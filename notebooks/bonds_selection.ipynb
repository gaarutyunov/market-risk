# %%
import datatable as dt
import pandas as pd
import numpy as numpy
import seaborn as sns
import matplotlib.pyplot as plt
from parsing.bonds import get_bonds_history
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %%
DT = get_bonds_history()

# %%
dt.unique(DT['SECID'])
# Out:
# <AxesSubplot:xlabel='TRADEDATE', ylabel='CLOSE'>

# %%
sns.lineplot(data=DT[:, ['TRADEDATE', 'CLOSE', 'SECID']].to_pandas(), x='TRADEDATE', y='CLOSE', hue='SECID')

# %%
DT[:, dt.update(count = dt.count()), dt.by('SECID')]

# %%
grouped = DT[0, :, dt.by('SECID')]

selected = grouped[:10, :, dt.sort(-dt.f.count)]
# Out:
# ['SU26207RMFS9',
#  'SU26209RMFS5',
#  'SU26211RMFS1',
#  'SU26212RMFS9',
#  'SU26215RMFS2']

# %%
selected
# Out:
# <Frame#7fe212fa4540 1x39>

# %%
selected[dt.f.SECID=='SU26209RMFS5', :]
# Out:
# <Frame#7fe212fa4600 5x1>

# %%
selected[:,'SECID']

# %%
DT[(secid in selected[0,'SECID'] for secid in DT[:, 'SECID']), :]

# %%
[secid.SECID for secid in DT[:, 'SECID']]
# Out:
# <AxesSubplot:xlabel='TRADEDATE', ylabel='CLOSE'>

# %%
sns.lineplot(data=selected[dt.f.SECID=='SU26209RMFS5', :].to_pandas(), x='TRADEDATE', y='CLOSE', hue='SECID')
# Out:
#           SECID BOARDID  SHORTNAME  PREVWAPRICE  YIELDATPREVWAPRICE  \
# 4  SU26207RMFS9    TQOB  ОФЗ 26207       86.480               12.26
# 5  SU26209RMFS5    TQOB  ОФЗ 26209       98.140               14.96
# 6  SU26211RMFS1    TQOB  ОФЗ 26211       95.333               13.75
# 7  SU26212RMFS9    TQOB  ОФЗ 26212       79.693               12.37
# 8  SU26215RMFS2    TQOB  ОФЗ 26215       92.521               13.62
#
#    COUPONVALUE  NEXTCOUPON  ACCRUEDINT  PREVPRICE  LOTSIZE  ...       LATNAME  \
# 4        40.64  2022-08-10       13.62     86.679        1  ...  OFZ-PD 26207
# 5        37.90  2022-07-20       17.08     98.165        1  ...  OFZ-PD 26209
# 6        34.90  2022-07-27       14.38     95.549        1  ...  OFZ-PD 26211
# 7        35.15  2022-07-27       14.48     79.980        1  ...  OFZ-PD 26212
# 8        34.90  2022-08-17       10.35     92.648        1  ...  OFZ-PD 26215
#
#    REGNUMBER CURRENCYID ISSUESIZEPLACED  LISTLEVEL  SECTYPE  COUPONPERCENT  \
# ...

# %%
# Out:
#             isin                   name    issuevalue  coupondate  recorddate  \
# 0   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2016-02-17  2016-02-16
# 1   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2016-08-17  2016-08-16
# 2   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2017-02-15  2017-02-14
# 3   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2017-08-16  2017-08-15
# 4   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2018-02-14  2018-02-13
# 5   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2018-08-15  2018-08-14
# 6   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2019-02-13  2019-02-12
# 7   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2019-08-14  2019-08-13
# 8   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2020-02-12  2020-02-11
# 9   RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2020-08-12  2020-08-11
# 10  RU000A0JS3W6  ОФЗ-ПД 26207 03/02/27  350000000000  2021-02-10  2021-02-09
# ...
